# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from Datasheet.svm_margin_plot import plot_svm_boundary

from sklearn.svm import SVC

# %%
data=pd.read_csv('Datasheet/mouse_viral_study.csv')

# %%
data.head()

# %%
sns.scatterplot(data=data, x='Med_1_mL',y='Med_2_mL' , hue='Virus Present')

# %%
X=data.drop('Virus Present', axis=1)
y=data['Virus Present']

# %%
y

# %%
X

# %%
model=SVC(kernel='linear',C=100)
model.fit(X,y)
# Out:
# SVC(C=100, kernel='linear')

# %%
plot_svm_boundary(model,X,y)
# Out:
# e:\Code2025\Machine-Learning_LearningRepository\.TheEnvForMachineLearning\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model2=SVC(kernel='linear',C=0.05)
model2.fit(X,y)
plot_svm_boundary(model2,X,y)
# Out:
# e:\Code2025\Machine-Learning_LearningRepository\.TheEnvForMachineLearning\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model3=SVC(kernel='rbf',C=1)
model3.fit(X,y)
plot_svm_boundary(model3,X,y)
# Out:
# e:\Code2025\Machine-Learning_LearningRepository\.TheEnvForMachineLearning\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
