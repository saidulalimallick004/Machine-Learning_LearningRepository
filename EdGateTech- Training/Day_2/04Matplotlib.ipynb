# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(1,10)

y=x*2

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)
plt.xlabel('X------>')
plt.ylabel('y------>')
plt.title('Scatter Plot')
plt.savefig('sam')
plt.show()

# %%
a=np.linspace(0,10,11)

b=a**4

# %%
m=np.arange(0,10)
n=m*2

# %% [markdown]
# * Crating Figure
